# %%
from analysis_plots import final_holders, provider_profit, market_participant_welfare,plot_final_holders_by_persona, plot_provider_profit_by_persona, plot_market_welfare_by_persona, plot_scenarios_grid

# %%
persona_dist = [{
    'Bandwagon': 0.7,
    'Neutral': 0.15,
    'Snob': 0.15
},{
    'Bandwagon': 0.15,
    'Neutral': 0.15,
    'Snob': 0.7
},{
    'Bandwagon': 0.15,
    'Neutral': 0.7,
    'Snob': 0.15
}]

# %%
import pandas as pd

df = pd.read_csv("results_certain.csv", encoding="utf-8")
print(df.head())

# 50 people, 3 iteration, 20 steps, 40 prices, 2 persona distributions
# Out:
#    RunId  iteration  Step  num_agents  num_data  initial_price  tau  \
# 0      6          0     0        1000      1000             23  0.0
# 1      6          0     0        1000      1000             23  0.0
# 2      6          0     0        1000      1000             23  0.0
# 3      6          0     0        1000      1000             23  0.0
# 4      6          0     0        1000      1000             23  0.0
#
#                                         persona_dist  wealth_alpha  \
# 0  {'Bandwagon': 0.7, 'Neutral': 0.15, 'Snob': 0.15}           2.0
# 1  {'Bandwagon': 0.7, 'Neutral': 0.15, 'Snob': 0.15}           2.0
# 2  {'Bandwagon': 0.7, 'Neutral': 0.15, 'Snob': 0.15}           2.0
# 3  {'Bandwagon': 0.7, 'Neutral': 0.15, 'Snob': 0.15}           2.0
# 4  {'Bandwagon': 0.7, 'Neutral': 0.15, 'Snob': 0.15}           2.0
#
#    wealth_scale  ...         w_1         w_n     alpha      lamb  l_n_minus_1  \
# ...

# %%
for dist in persona_dist:
    final_holders(df, dist)
    provider_profit(df, dist)
    market_participant_welfare(df, dist)
# Out:
# Mean final holders by price:
# Mean provider profit by price:
# Mean final holders by price:
# Mean provider profit by price:
# Mean final holders by price:
# Mean provider profit by price:

# %%
plot_final_holders_by_persona(df)
plot_provider_profit_by_persona(df)
plot_market_welfare_by_persona(df)

# %%
plot_scenarios_grid(df, persona_dist)
# Out:
# /Users/oyama-kenshin/Desktop/Vault/05_Codes/analysis_plots.py:201: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model_level_data['HoldersRatio'] = model_level_data['Holders'] / num_agents
# /Users/oyama-kenshin/Desktop/Vault/05_Codes/analysis_plots.py:201: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model_level_data['HoldersRatio'] = model_level_data['Holders'] / num_agents
# /Users/oyama-kenshin/Desktop/Vault/05_Codes/analysis_plots.py:201: SettingWithCopyWarning:
# ...
