# %%
import mesa
from mesa import Model, Agent
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
class Participants(Agent):
    def __init__(self, model):
        super().__init__(model)
        self.has_token = False
        self.purchase_price = None # 初期状態では購入価格なし

        # 資産と効用
        self.wealth = int(self.random.normalvariate(100, 20))
        self.wealth = max(0, self.wealth)
        self.utility = int(self.random.normalvariate(80, 15))
        self.utility = max(0, self.utility)
        
        self.is_listing = False
        self.listing_price = None

        #すでにTokenを保有したことがあるか
        self.has_ever_held_token = False

    def decide_sell_price(self):
        """効用 + 20% ± 5% の価格を決定する"""
        base_price = self.utility
        price_with_markup = base_price * (1 + self.model.markup_rate)
        random_factor = self.random.uniform(0.95, 1.05)
        
        final_price = price_with_markup * random_factor
        return final_price

    def decide_and_list_if_applicable(self):
        """売り手としての行動フェーズ"""
        if self.has_token and not self.is_listing:
            if self.random.random() < self.model.listing_probability:
                price_to_list = self.decide_sell_price()
                self.model.place_sell_order(price_to_list, self)
                self.is_listing = True
                self.listing_price = price_to_list
                print(f"Agent {self.unique_id} (Utility: {self.utility}) listed token for {price_to_list:.2f}")

    def buy_if_interested(self):
        """買い手としての行動フェーズ"""
        # トークンを既に持っているエージェントは購入しない
        if self.has_ever_held_token:
            return

        # 市場に売り注文があるか確認
        if not self.model.sell_orders:
            return

        # 最も安い注文を取得
        cheapest_order = self.model.sell_orders[0]
        price = cheapest_order['price']
        seller = cheapest_order['agent']

        # 購入条件をチェック
        if self.utility >= price and self.wealth >= price:
            # 取引を実行
            self.model.execute_trade(self, seller, price)
            print(f"Agent {self.unique_id} bought token from Agent {seller.unique_id} for {price:.2f}")


class DataMarket(Model):
    def __init__(self, num, initial_token_holders, listing_probability, markup_rate=0.2, seed=None):
        super().__init__(seed=seed)
        self.num_agents = num
        self.listing_probability = listing_probability
        self.markup_rate = markup_rate
        self.steps = 0 # ステップカウンターを追加

        # AgentSet を使ってエージェントを生成・管理
        self.participants = Participants.create_agents(model=self, n=self.num_agents)

        # 初期保有者を設定
        initial_holders = self.random.sample(self.participants, k=initial_token_holders)
        for agent in initial_holders:
            agent.has_token = True
            agent.purchase_price = 100 # 前提：初期保有者は100で購入済み
            agent.has_ever_held_token = True
            #print(f"Participant {agent.unique_id} is set as an initial token holder.")

        self.sell_orders = []

    def place_sell_order(self, price, agent):
        """市場に売り注文を追加し、価格の安い順にソートする"""
        self.sell_orders.append({'price': price, 'agent': agent})
        self.sell_orders.sort(key=lambda x: x['price'])

    def execute_trade(self, buyer, seller, price):
        """売買取引を成立させる"""
        # 買い手の状態変化
        buyer.wealth -= price
        buyer.has_token = True
        buyer.purchase_price = price # 新しい購入価格を記録
        buyer.has_ever_held_token = True

        # 売り手の状態変化
        seller.wealth += price
        seller.has_token = False
        seller.is_listing = False
        seller.listing_price = None

        # 成立した注文を市場から削除
        order_to_remove = next(order for order in self.sell_orders if order['agent'] == seller)
        self.sell_orders.remove(order_to_remove)

    def step(self):
        """1ステップの処理を定義"""
        print(f"--- Step {self.steps} ---")
        
        # フェーズ1: 売り手がランダムな順序で出品を試みる
        print("Listing phase...")
        self.participants.shuffle_do("decide_and_list_if_applicable")
        
        # フェーズ2: 買い手がランダムな順序で購入を試みる
        print("Buying phase...")
        self.participants.shuffle_do("buy_if_interested")

# %%
# Run the simulation
model = DataMarket(num = 100, initial_token_holders= 50, listing_probability=0.1, markup_rate=0.2, seed=42)
lowest_price = {}

for i in range(100):
    model.step()
    lowest_price[model.steps] = model.sell_orders[0]["price"]
# Out:
# --- Step 1 ---
# Listing phase...
# Agent 37 (Utility: 90) listed token for 105.28
# Agent 9 (Utility: 70) listed token for 87.86
# Agent 23 (Utility: 94) listed token for 115.76
# Agent 39 (Utility: 77) listed token for 90.00
# Agent 69 (Utility: 106) listed token for 124.50
# Agent 20 (Utility: 62) listed token for 72.42
# Agent 12 (Utility: 48) listed token for 59.29
# Buying phase...
# Agent 38 bought token from Agent 12 for 59.29
# Agent 7 bought token from Agent 20 for 72.42
# Agent 31 bought token from Agent 9 for 87.86
# Agent 5 bought token from Agent 39 for 90.00
# Agent 94 bought token from Agent 37 for 105.28
# --- Step 2 ---
# Listing phase...
# Agent 2 (Utility: 77) listed token for 95.83
# Agent 89 (Utility: 78) listed token for 96.45
# Agent 44 (Utility: 86) listed token for 104.30
# Buying phase...
# Agent 15 bought token from Agent 2 for 95.83
# Agent 8 bought token from Agent 89 for 96.45
# --- Step 3 ---
# Listing phase...
# Agent 91 (Utility: 83) listed token for 101.61
# Agent 38 (Utility: 77) listed token for 91.72
# Agent 77 (Utility: 62) listed token for 76.87
# Agent 35 (Utility: 65) listed token for 74.85
# Buying phase...
# Agent 97 bought token from Agent 35 for 74.85
# Agent 51 bought token from Agent 77 for 76.87
# Agent 80 bought token from Agent 38 for 91.72
# --- Step 4 ---
# Listing phase...
# Agent 31 (Utility: 106) listed token for 122.16
# Agent 75 (Utility: 74) listed token for 85.20
# Buying phase...
# Agent 58 bought token from Agent 75 for 85.20
# --- Step 5 ---
# Listing phase...
# Agent 86 (Utility: 58) listed token for 67.52
# Agent 56 (Utility: 92) listed token for 112.02
# Agent 22 (Utility: 65) listed token for 79.21
# Agent 40 (Utility: 67) listed token for 79.79
# Agent 29 (Utility: 71) listed token for 86.66
# Buying phase...
# Agent 93 bought token from Agent 86 for 67.52
# Agent 3 bought token from Agent 22 for 79.21
# Agent 61 bought token from Agent 40 for 79.79
# --- Step 6 ---
# Listing phase...
# Agent 95 (Utility: 97) listed token for 121.58
# Agent 57 (Utility: 73) listed token for 86.66
# Agent 73 (Utility: 85) listed token for 99.77
# Agent 47 (Utility: 60) listed token for 69.17
# Agent 61 (Utility: 86) listed token for 98.57
# Agent 60 (Utility: 47) listed token for 55.68
# Buying phase...
# Agent 1 bought token from Agent 60 for 55.68
# Agent 98 bought token from Agent 47 for 69.17
# --- Step 7 ---
# Listing phase...
# Agent 14 (Utility: 94) listed token for 110.96
# Agent 1 (Utility: 72) listed token for 90.56
# Agent 54 (Utility: 78) listed token for 92.51
# Buying phase...
# --- Step 8 ---
# Listing phase...
# Agent 63 (Utility: 85) listed token for 104.29
# Agent 67 (Utility: 88) listed token for 110.22
# Agent 93 (Utility: 68) listed token for 85.53
# Buying phase...
# Agent 66 bought token from Agent 93 for 85.53
# --- Step 9 ---
# Listing phase...
# Agent 62 (Utility: 62) listed token for 73.31
# Agent 65 (Utility: 98) listed token for 118.75
# Agent 48 (Utility: 66) listed token for 82.38
# Agent 16 (Utility: 82) listed token for 97.76
# Agent 30 (Utility: 59) listed token for 69.04
# Buying phase...
# Agent 52 bought token from Agent 30 for 69.04
# Agent 11 bought token from Agent 62 for 73.31
# Agent 53 bought token from Agent 48 for 82.38
# --- Step 10 ---
# Listing phase...
# Agent 11 (Utility: 75) listed token for 87.52
# Buying phase...
# --- Step 11 ---
# Listing phase...
# Agent 83 (Utility: 71) listed token for 85.65
# Agent 98 (Utility: 87) listed token for 108.55
# Buying phase...
# --- Step 12 ---
# Listing phase...
# Agent 52 (Utility: 76) listed token for 94.01
# Buying phase...
# --- Step 13 ---
# Listing phase...
# Agent 79 (Utility: 106) listed token for 129.86
# Agent 7 (Utility: 73) listed token for 85.47
# Agent 66 (Utility: 86) listed token for 102.02
# Buying phase...
# --- Step 14 ---
# Listing phase...
# Agent 85 (Utility: 74) listed token for 88.28
# Agent 100 (Utility: 93) listed token for 114.85
# Agent 90 (Utility: 77) listed token for 94.34
# Agent 51 (Utility: 87) listed token for 99.53
# Agent 88 (Utility: 82) listed token for 97.03
# Buying phase...
# --- Step 15 ---
# Listing phase...
# Agent 3 (Utility: 88) listed token for 100.36
# Agent 55 (Utility: 100) listed token for 114.55
# Buying phase...
# --- Step 16 ---
# Listing phase...
# Agent 80 (Utility: 98) listed token for 112.79
# Buying phase...
# --- Step 17 ---
# Listing phase...
# Agent 25 (Utility: 87) listed token for 108.91
# Buying phase...
# --- Step 18 ---
# Listing phase...
# Buying phase...
# --- Step 19 ---
# Listing phase...
# Agent 5 (Utility: 97) listed token for 116.75
# Agent 32 (Utility: 89) listed token for 102.89
# Buying phase...
# --- Step 20 ---
# Listing phase...
# Agent 72 (Utility: 89) listed token for 106.61
# Buying phase...
# --- Step 21 ---
# Listing phase...
# Buying phase...
# --- Step 22 ---
# Listing phase...
# Buying phase...
# --- Step 23 ---
# Listing phase...
# Agent 6 (Utility: 109) listed token for 131.12
# Buying phase...
# --- Step 24 ---
# Listing phase...
# Buying phase...
# --- Step 25 ---
# Listing phase...
# Agent 43 (Utility: 72) listed token for 88.72
# Agent 58 (Utility: 88) listed token for 105.29
# Buying phase...
# --- Step 26 ---
# Listing phase...
# Agent 53 (Utility: 84) listed token for 101.94
# Buying phase...
# --- Step 27 ---
# Listing phase...
# Agent 8 (Utility: 102) listed token for 122.38
# Buying phase...
# --- Step 28 ---
# Listing phase...
# Buying phase...
# --- Step 29 ---
# Listing phase...
# Buying phase...
# --- Step 30 ---
# Listing phase...
# Buying phase...
# --- Step 31 ---
# Listing phase...
# Agent 15 (Utility: 99) listed token for 119.26
# Agent 42 (Utility: 66) listed token for 79.29
# Buying phase...
# Agent 99 bought token from Agent 42 for 79.29
# --- Step 32 ---
# Listing phase...
# Agent 49 (Utility: 108) listed token for 124.52
# Agent 18 (Utility: 93) listed token for 107.35
# Buying phase...
# --- Step 33 ---
# Listing phase...
# Buying phase...
# --- Step 34 ---
# Listing phase...
# Buying phase...
# --- Step 35 ---
# Listing phase...
# Buying phase...
